# %% [markdown]
# <a href="https://colab.research.google.com/github/spyysalo/dl-binf-summer-school-2026/blob/main/generation_and_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generation and embeddings
#
# ## Unpacking `pipeline`
#
# The following illustrates some parts that go into text generation using the `pipeline` class.

# %% [markdown]
# First install the [transformers](https://huggingface.co/docs/transformers/index) package.

# %%
# !pip install --quiet transformers

# %% [markdown]
# Next, load a `pipeline` for text generation with a small model.

# %%
from transformers import pipeline

MODEL_NAME = 'HuggingFaceTB/SmolLM-135M'

pipe = pipeline(
    'text-generation',
    model=MODEL_NAME,
    device_map='auto',
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/272 [00:00<?, ?it/s]

# %% [markdown]
# We can conveniently generate text using the high-level abstraction that `pipeline` provides:

# %%
prompt = 'The capital of Denmark is'

print(pipe(prompt, max_new_tokens=16)[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=16) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# The capital of Denmark is Copenhagen, one of the largest cities in the world. In addition to being the

# %% [markdown]
# For simplicity, let's look at generating one word using greedy decoding, i.e. simply selecting the word that's most likely according to the model.

# %%
params = {
    'do_sample': False,
    'max_new_tokens': 1,
    'generation_config': None,
}

print(pipe(prompt, **params)[0]['generated_text'])
# Out:
# The capital of Denmark is Copenhagen

# %% [markdown]
# Now, let's look at what's going on behind the `pipeline` abstraction. First, here's the model

# %%
model = pipe.model
print(model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(49152, 576)
#     (layers): ModuleList(
#       (0-29): 30 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=576, out_features=576, bias=False)
#           (k_proj): Linear(in_features=576, out_features=192, bias=False)
#           (v_proj): Linear(in_features=576, out_features=192, bias=False)
#           (o_proj): Linear(in_features=576, out_features=576, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=576, out_features=1536, bias=False)
#           (up_proj): Linear(in_features=576, out_features=1536, bias=False)
#           (down_proj): Linear(in_features=1536, out_features=576, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm((576,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((576,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((576,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=576, out_features=49152, bias=False)
# )

# %% [markdown]
# The model doesn't deal with text (character sequences) directly, but rather with token indices. The mapping between running text and token indices is implemented by a tokenizer.

# %%
tokenizer = pipe.tokenizer

# %% [markdown]
# Let's have a look at the mapping between our prompt and the token indices.

# %%
input_ = tokenizer(prompt)

print(input_)
# Out:
# {'input_ids': [504, 3575, 282, 15644, 314], 'attention_mask': [1, 1, 1, 1, 1]}

# %% [markdown]
# That's the actual input to the model, and `input_ids` are the token indices. (We can ignore the `attention_mask` here.)
#
# The tokenizer can map these back to text

# %%
print(tokenizer.convert_ids_to_tokens(input_.input_ids))
# Out:
# ['The', 'Ġcapital', 'Ġof', 'ĠDenmark', 'Ġis']

# %% [markdown]
# (The `Ġ` there encodes space; this representation is a minor quirk of the GPT tokenizer.)
#
# Because the token ids represent both visible characters and space, the full input string can be reconstructed accurately:

# %%
print(tokenizer.decode(input_.input_ids))
# Out:
# The capital of Denmark is

# %% [markdown]
# We can invoke the model directly with the encoded input. Here we need to ask the tokenizer to generate pytorch tensors due to some implementation details, but the information content is the same.

# %%
input_ = tokenizer(prompt, return_tensors='pt')

print(input_)
# Out:
# {'input_ids': tensor([[  504,  3575,   282, 15644,   314]]), 'attention_mask': tensor([[1, 1, 1, 1, 1]])}

# %%
output = model(**input_)
print(output.logits)
# Out:
# tensor([[[ -3.5625, -11.6875, -11.6875,  ...,  -7.3750,  -7.0312,  -9.8750],
#          [  2.0781,  -8.1875,  -8.3125,  ...,  -7.7188,  -5.2812,  -9.3750],
#          [-10.5000, -20.7500, -20.7500,  ..., -16.1250, -14.0625, -19.2500],
#          [ 12.7500,  -4.3125,  -4.5938,  ...,   1.7422,   1.8828,  -2.1719],
#          [ -0.1187, -13.3125, -13.5625,  ...,  -8.6250,  -3.8594, -12.5625]]],
#        dtype=torch.bfloat16, grad_fn=<UnsafeViewBackward0>)

# %% [markdown]
# The primary output of the model are the logits, which correspond to unnormalized scores for each token index. We're interested in the scores for the last token. (The first dimension here is for the batch, and we have a batch of one.)

# %%
print(output.logits.shape)

logits = output.logits[0][-1]
print(logits)
# Out:
# torch.Size([1, 5, 49152])
# tensor([ -0.1187, -13.3125, -13.5625,  ...,  -8.6250,  -3.8594, -12.5625],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)

# %% [markdown]
# For greedy decoding, we can just take the argmax, which gives us the index of the most likely next word.

# %%
logits.argmax()
# Out:
# tensor(27101)

# %%
tokenizer.convert_ids_to_tokens([logits.argmax()])
# Out:
# ['ĠCopenhagen']

# %% [markdown]
# If we wanted to continue generating more than one word, we would simply append this index to `input_ids` and invoke the model again.

# %% [markdown]
# ---

# %% [markdown]
# ## Embeddings
#
# The transformer blocks operate with continuous representations rather than discrete word identifiers. To map the `input_ids` to a continuous representation, the first step in the model application is to look up a learned (context-independent) embedding. These are similar to the embeddings generated by methods such as `word2vec`.
#
# (We already saw an instance of mapping from the continuous representations to discrete IDs on the output through `argmax`)
#
# Let's have a quick look at the embeddings for this model.

# %%
embedding = model.get_input_embeddings()
print(embedding)
# Out:
# Embedding(49152, 576)

# %% [markdown]
# Here the first value is the number of tokens in the model vocabulary and the second the hidden dimension of the model.

# %% [markdown]
# Let's write a few functions for getting IDs and embeddings for individual words and look at the IDs and embeddings for the words "dog", "cat", and "hat".

# %%
def get_id(word):
  ids = tokenizer(' ' + word).input_ids    # add initial space
  assert len(ids) == 1, f'multiple tokens for {word}'
  return ids[0]

dog_id = get_id('dog')
cat_id = get_id('cat')
hat_id = get_id('hat')

# %% [markdown]
# The IDs themselves are arbitrary and meaningless outside of their reference to the embedding matrix:

# %%
print(dog_id, cat_id, hat_id)
# Out:
# 2767 2644 9968

# %% [markdown]
# Let's grab the corresponding embeddings

# %%
import torch

def get_embedding(id_):
  return embedding(torch.tensor(id_))

dog_emb = get_embedding(dog_id)
cat_emb = get_embedding(cat_id)
hat_emb = get_embedding(hat_id)

# %% [markdown]
# These are vectors of the hidden dimensionality of the model

# %%
print(dog_emb.shape)
# Out:
# torch.Size([576])

# %% [markdown]
# The embeddings cannot be interpreted in isolation, but are "understood" by the model.

# %%
print(dog_emb[:100])
# Out:
# tensor([-0.0126,  0.0339,  0.1357, -0.0303,  0.0640,  0.1357,  0.0044,  0.1660,
#          0.1196, -0.0820, -0.1094, -0.0918, -0.1719,  0.2021, -0.0713, -0.0491,
#          0.1533,  0.0172,  0.1177, -0.1426, -0.0664, -0.0469,  0.0298,  0.1660,
#          0.1348,  0.1289, -0.1240, -0.1221, -0.1099, -0.0742,  0.1660, -0.0938,
#         -0.0608,  0.1162,  0.0154,  0.1611, -0.0398,  0.1357, -0.2617,  0.1758,
#          0.0874, -0.0184,  0.0603,  0.0850,  0.0588,  0.1514,  0.0903,  0.0605,
#          0.1279,  0.1641,  0.0153, -0.3066,  0.0222,  0.2021, -0.0488, -0.1211,
#         -0.0459,  0.0334,  0.0146,  0.1230,  0.0115,  0.1211,  0.0396,  0.0884,
#          0.0267, -0.1680, -0.0400,  0.0087, -0.2715, -0.1445,  0.0471,  0.0447,
#          0.0618,  0.0437, -0.0138,  0.0211,  0.0723,  0.0952, -0.1328, -0.1953,
#         -0.0854,  0.1543, -0.0014, -0.1748,  0.0698, -0.0952, -0.0011,  0.0081,
#         -0.1245,  0.1533, -0.1514, -0.1846, -0.1787, -0.1963, -0.0219,  0.2754,
#          0.0227, -0.1445,  0.0167, -0.1377], dtype=torch.bfloat16,
#        grad_fn=<SliceBackward0>)

# %% [markdown]
# The embeddings can also be used e.g. to compare the similarity of (context-free) word representations:

# %%
from torch.nn.functional import cosine_similarity

def compare(emb1, emb2):
  return cosine_similarity(emb1.unsqueeze(0), emb2.unsqueeze(0)).item()

print('sim("cat", "dog"):', compare(cat_emb, dog_emb))
print('sim("cat", "hat"):', compare(cat_emb, hat_emb))
# Out:
# sim("cat", "dog"): 0.5703125
# sim("cat", "hat"): 0.1640625

# %% [markdown]
# ---
#
# **TASK:** In GPT-like models such as the above the final layer representation at each position is trained to predict the next token, while in BERT-like models it is trained to predict the token at that position. Because of this, we can use the final layer representation of BERT-like models as contextual embeddings.
#
# Read and understand the following code. What is demonstrated here? Come up with at least one other example showing the effect by changing `focus_word`, `reference_word`, and `sentences`.

# %%
from transformers import AutoModel, AutoTokenizer

MODEL_NAME = 'google-bert/bert-base-uncased'

model = AutoModel.from_pretrained(MODEL_NAME)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: google-bert/bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
embedding = model.get_input_embeddings()

focus_word = 'pupil'
reference_word = 'eye'

sentences = [
    'The pupil dilated in the dark.',
    'The pupil raised her hand',
]

def get_id(word):
  ids = tokenizer(word, add_special_tokens=False).input_ids
  assert len(ids) == 1, f'multiple tokens for {word}'
  return ids[0]

def get_embedding(id_):
  return embedding(torch.tensor(id_))

def word_position(word, input_ids):
  tokens = tokenizer.convert_ids_to_tokens(input_ids)
  return tokens.index(word)

input_emb = get_embedding(get_id(focus_word))
reference_emb = get_embedding(get_id(reference_word))

for sentence in sentences:
  tokenized = tokenizer(sentence, return_tensors='pt')
  position = word_position(focus_word, tokenized.input_ids[0])
  output = model(**tokenized)
  output_emb = output.last_hidden_state[0, position]
  print(f'similarity of "{focus_word}" to "{reference_word}" in context "{sentence}":', compare(output_emb, reference_emb))
# Out:
# similarity of "pupil" to "eye" in context "The pupil dilated in the dark.": 0.043825797736644745
# similarity of "pupil" to "eye" in context "The pupil raised her hand": -0.016847286373376846
